# %% [markdown]
# <a href="https://colab.research.google.com/github/starkjones/Vienna-Air-BnB-Analysis/blob/main/Ecuador_Airbnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = '/content/drive/MyDrive/dataset_airbnb-scraper_2022-12-18_03-59-36-898_ML.xlsx'
df = pd.read_excel(data)
df.head(10)
# Out:
#                                     address  location/lat  location/lng  \
# 0                   Cuenca , Azuay, Ecuador      -2.88697     -78.95881
# 1                 Quito, Pichincha, Ecuador      -0.18413     -78.47900
# 2                    Cuenca, Azuay, Ecuador      -2.92100     -78.99900
# 3                    Cuenca, Azuay, Ecuador      -2.88815     -79.00389
# 4  Baños de Agua Santa, Tungurahua, Ecuador      -1.38815     -78.41738
# 5                    Cuenca, Azuay, Ecuador      -2.90000     -79.02000
# 6                             Loja, Ecuador      -4.00649     -79.19962
# 7                 Quito, Pichincha, Ecuador      -0.18035     -78.48102
# 8                 Quito, Pichincha, Ecuador      -0.18930     -78.48296
# 9                 Quito, Pichincha, Ecuador      -0.19468     -78.48185
#
#                                                 name  numberOfGuests  \
# 0  3BR Duplex, Parking, Laundry, 24hr vídeo secur...               9
# ...

# %%
# check for duplciates:

df.duplicated().sum()
# Out:
# 0

# %%
# check column datsatypes:

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 64 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   address                                      280 non-null    object
#  1   location/lat                                 280 non-null    float64
#  2   location/lng                                 280 non-null    float64
#  3   name                                         280 non-null    object
#  4   numberOfGuests                               280 non-null    int64
#  5   occupancy percentage                         280 non-null    float64
#  6   reviews/0/rating                             248 non-null    float64
#  7   reviews/1/rating                             234 non-null    float64
#  8   reviews/2/rating                             223 non-null    float64
# ...

# %%
# check for missing values:

df.isna().sum()
# Out:
# address                                  0
# location/lat                             0
# location/lng                             0
# name                                     0
# numberOfGuests                           0
#                                       ...
# reviews/29/localizedReview/response    275
# reviews/29/rating                      157
# roomType                                 0
# stars                                   57
# url                                      0
# Length: 64, dtype: int64
